# %%
# !pip install torch torchvision opencv-python numpy loguru thop scipy lap cython_bbox pycocotools tabulate ultralytics torchreid

# %%
# !pip install git+https://github.com/FoundationVision/ByteTrack

# %%
# !pip install git+https://github.com/KaiyangZhou/deep-person-reid.git

# %%
# !cp /usr/local/lib/python3.11/dist-packages/yolox/tracker/matching.py ./matching.py

# %%
# !cp ./matching.py /usr/local/lib/python3.11/dist-packages/yolox/tracker/matching.py

# %%
# !cp /usr/local/lib/python3.11/dist-packages/yolox/tracker/byte_tracker.py ./byte_tracker.py

# %%
# !cp ./byte_tracker.py /usr/local/lib/python3.11/dist-packages/yolox/tracker/byte_tracker.py

# %%
# !python reid_metrics.py

# %%
# !python detection_metrics.py

# %%
# !python main.py

# %%
# !python finetuning_reid.py

# %%
# !cp /usr/local/lib/python3.11/dist-packages/torchreid/utils/torchtools.py ./torchtools.py

# %%
# !cp ./torchtools.py /usr/local/lib/python3.11/dist-packages/torchreid/utils/torchtools.py

# %%
from reid_metrics import calc_metrics
calc_metrics('log/custom_reid/model/model.pth.tar-1')
